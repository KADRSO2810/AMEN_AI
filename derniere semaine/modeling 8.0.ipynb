# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# Charger ta dataframe finale (à adapter selon ton chemin)
df = pd.read_csv(r"C:\Users\zizou\OneDrive\Desktop\stage 3ème\day 2\csvfiles\dataframefinale.csv",sep=";")
# Afficher un aperçu
print(df.head())
print("\nColonnes de la dataframe :", list(df.columns))
# Out:
#   dataloadingdate  Jour  Mois  NumeroSemaine  Trimestre  JourSemaineNum  \
# 0      01/07/2025     1     7             27          3               1
# 1      01/07/2025     1     7             27          3               1
# 2      01/07/2025     1     7             27          3               1
# 3      01/07/2025     1     7             27          3               1
# 4      01/07/2025     1     7             27          3               1
#
#   JourSemaine          ISIN                Libellé  Nombre de Titres  Montant  \
# 0     Tuesday  TN0008000739  BTA 7,4% Fevrier 2030            1459.0    1.500
# 1     Tuesday  TN0008000739  BTA 7,4% Fevrier 2030             291.0    0.300
# 2     Tuesday  TNMCPXLL1EE2  EMP NAT 2023 T4 CB TV           50000.0    5.000
# 3     Tuesday  TNMCPXLL1EE2  EMP NAT 2023 T4 CB TV           10000.0    1.000
# 4     Tuesday  TN0008000606    BTA 6,7% Avril 2028            5660.0    5.742
#
#    Echéance  Taux
# 0      62.0   7.6
# 1     183.0   7.5
# ...

# %%
# Définir le nom de la cible
target = 'Montant'  # ou 'Montant_log' si tu préfères log-transformer la cible

# Transformation log (optionnelle mais recommandée pour stabiliser la variance)
y = df[target]
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.histplot(y, kde=True)
plt.title("Distribution Montant original")

y_log = np.log1p(y)  # log(1+x) pour gérer les 0

plt.subplot(1,2,2)
sns.histplot(y_log, kde=True)
plt.title("Distribution Montant log-transformé")

plt.show()

# On choisit d’utiliser y_log comme cible
y = y_log
target = 'Montant_log'

# %%
# On ne garde que les colonnes numériques comme features
X_numeric = X.select_dtypes(include=[np.number])

print(f"Colonnes numériques utilisées comme features : {list(X_numeric.columns)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # On ne garde que les colonnes numériques comme features
# ----> 2 X_numeric = X.select_dtypes(include=[np.number])
#       4 print(f"Colonnes numériques utilisées comme features : {list(X_numeric.columns)}")
#
# NameError: name 'X' is not defined
